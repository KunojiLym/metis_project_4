# %%
import pandas as pd
import numpy as np
import pickle

from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow, Flow
from google.auth.transport.requests import Request
import json

import re
import string
import datetime

from joblib import dump, load, parallel_backend
import os

RANDOM = 42

# %%
with open('data/googlefactcheck.key', 'r') as key_file:
    key = key_file.read()

# %%
key
# Out:
# 'AIzaSyA5cBLSCeRjt0aq_phXm2UGyJ3HKO-iVIY'

# %%
creds = None
SCOPE = ["https://www.googleapis.com/auth/userinfo.profile", "https://www.googleapis.com/auth/userinfo.email", "openid"]

# The file token.pickle stores the user's access and refresh tokens, and is
# created automatically when the authorization flow completes for the first
# time.
    
if os.path.exists('data/token.pickle'):
    with open('data/token.pickle', 'rb') as token:
        creds = pickle.load(token)
        
# If there are no (valid) credentials available, let the user log in.
if not creds or not creds.valid:
    if creds and creds.expired and creds.refresh_token:
        creds.refresh(Request())
    else:
        flow = InstalledAppFlow.from_client_secrets_file('data/googlefactcheck_program.json', SCOPE)
        creds = flow.run_local_server(port=0)
    # Save the credentials for the next run
    with open('data/token.pickle', 'wb') as token:
        pickle.dump(creds, token)

# %%
service = build('factchecktools', 'v1alpha1', credentials=creds)

# %%
first_request = {'languageCode': 'en',
                 'reviewPublisherSiteFilter': 'politifact.com', 
                 'pageSize': 100,
                 'key': key }

# %%
import requests

r = requests.get(url = "https://factchecktools.googleapis.com/v1alpha1/claims:search", params = first_request)

# %%
next_request = {'languageCode': 'en',
                 'reviewPublisherSiteFilter': 'politifact.com', 
                 'pageSize': 100,
                 'pageToken': dict(r.json())['nextPageToken'],
                 'key': key }

r = requests.get(url = "https://factchecktools.googleapis.com/v1alpha1/claims:search", params = next_request)

# %%
dict(r.json())
# Out:
# {'claims': [{'text': "Speaking about border apprehensions, said “We have some of the best numbers we've ever had. Southern border, the best numbers we've ever had.”",
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-14T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/20/donald-trump/fact-checking-donald-trumps-claim-best-numbers-bor/',
#      'title': "Fact-checking Donald Trump's claim of 'best numbers' at the border",
#      'textualRating': 'Half True',
#      'languageCode': 'en'}]},
#   {'text': '“If you look at the one (hydroxychloroquine) survey, the only bad survey, they were giving it to people that were in very bad shape. They were very old. Almost dead.”',
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-19T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/20/donald-trump/trump-wrong-hydroxychloroquine-studies-only-gave-d/',
#      'title': 'Trump wrong that hydroxychloroquine studies only gave drug to dying patients',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'If you paid rent in March or April, “they got to give” you your money back.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-04-22T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/20/facebook-posts/no-theres-no-covid-19-law-requires-rent-or-mortgag/',
#      'title': "No, there's no COVID-19 law that requires rent (or mortgage) refunds",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Says GOP Wisconsin Sen. Patrick Testin is responsible for lost $25M in federal funding, because he refused “to do his job.”',
#    'claimant': 'Wisconsin State Senate',
#    'claimDate': '2020-05-08T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/20/wisconsin-state-senate-democrats/gop-state-sen-patrick-testin-blame-25m-lost-corona/',
#      'title': 'Is GOP state Sen. Patrick Testin to blame for $25M in lost coronavirus relief? Not quite.',
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': '“Due to the large number of people who will refuse the forthcoming COVID-19 vaccine because it will include tracking microchips, the Gates Foundation is now spending billions to ensure that all medical and dental injections and procedures include the chips.”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-13T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/20/facebook-posts/no-gates-foundation-isnt-pushing-microchips-all-me/',
#      'title': "No, the Gates Foundation isn't pushing microchips with all medical procedures",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Bill Gates Explains That The COVID Vaccine Will Use Experimental Technology And Permanently Alter Your DNA”',
#    'claimant': 'Facebook post',
#    'claimDate': '2020-05-15T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/20/facebook-posts/no-specific-covid-19-vaccine-experimental-or-other/',
#      'title': 'Blog post wrong on what Bill Gates said about COVID-19 vaccine',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': "“On the Southern border, as you know, the wall is going up, it's going up very rapidly. We're at 182 miles.”",
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-19T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/20/donald-trump/facts-donald-trumps-claim-182-miles-border-wall-co/',
#      'title': "The facts on Donald Trump's claim of 182 miles of border wall construction",
#      'textualRating': 'Half True',
#      'languageCode': 'en'}]},
#   {'text': '“Rogue” Michigan official sent absentee ballots to 7.7 million people “illegally and without authorization” ahead of the primaries and general election.',
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-20T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/20/donald-trump/trump-falsely-claims-michigan-sent-ballots-all-vot/',
#      'title': 'Trump falsely claims Michigan illegally sent ballots to all voters',
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': 'Kitchen worker in viral video is potentially spreading coronavirus by blowing into food containers.',
#    'claimant': 'Viral image',
#    'claimDate': '2020-05-14T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/viral-image/video-kitchen-worker-blowing-food-wrappers-least-t/',
#      'title': 'Video of kitchen worker blowing on food wrappers is at least three years old',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Says “the feds closed the courtroom” when El Chapo started naming Democrats he paid off.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-11T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/facebook-posts/no-el-chapo-didnt-testify-he-paid-democrats/',
#      'title': "No, El Chapo didn't testify that he paid off Democrats",
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': '“Hydroxychloroquine cures this ‘virus.’ It just so happens this is the treatment used for radiation sickness!!”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-14T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/facebook-posts/hydroxychloroquine-not-proven-treat-covid-19-or-ra/',
#      'title': 'Hydroxychloroquine is not proven to treat COVID-19 or radiation sickness',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Says Gov. Tony Evers “is proposing a new plan, a 150 day shutdown of the state (5 MONTHS!) followed by a 120 day extension.”',
#    'claimant': 'Facebook',
#    'claimDate': '2020-05-16T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/facebook-posts/no-gov-tony-evers-did-not-want-shut-down-state-fiv/',
#      'title': 'No, Gov. Tony Evers did not want to shut down Wisconsin for nine months',
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': 'Says wearing face masks is more harmful to your health than going without one.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-08T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/facebook-posts/theres-no-evidence-wearing-standard-masks-harmful-/',
#      'title': "There's no evidence that wearing standard masks is harmful to your health",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Autopsies prove that COVID-19 is” a blood clot, not pneumonia, “and ought to be fought with antibiotics” and the whole world has been wrong in treating the “so-called” pandemic.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-11T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/facebook-posts/no-covid-19-wont-respond-antibiotics-despite-findi/',
#      'title': "No, COVID-19 won't respond to antibiotics, despite findings from new autopsies",
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': '"States like New York, Illinois and California have been vocal in their demands for funding to bail out their pension systems, which were failing long before the COVID-19 outbreak, and other programs that aren’t related to this crisis."',
#    'claimant': 'Andy Biggs',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/andy-biggs/new-york-pension-fund-does-not-need-federal-bailou/',
#      'title': 'New York pension fund does not need a federal bailout',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Anthony Fauci was on the Clinton Foundation board for 20 years and “currently serves on Gates Foundation.”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-12T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/facebook-posts/no-fauci-wasnt-clinton-foundation-board-two-decade/',
#      'title': "No, Fauci wasn't on the Clinton Foundation board for two decades",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Says President Donald Trump is “morbidly obese.”',
#    'claimant': 'Nancy Pelosi',
#    'claimDate': '2020-05-19T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/nancy-pelosi/no-he-not-morbidly-obese/',
#      'title': "Donald Trump doesn't meet the definition of morbidly obese",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'If masks prevent coronavirus, governors would have given them to prison inmates instead of releasing them.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-14T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/19/facebook-posts/states-do-use-masks-contain-covid-19-prisons/',
#      'title': 'States do use masks to contain COVID-19 in prisons',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Cannabis may stop coronavirus from infecting people, study finds.”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-14T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/18/facebook-posts/fact-checking-whether-cannabis-may-prevent-covid-1/',
#      'title': 'Might cannabis prevent COVID-19? Preliminary study provides only scant evidence',
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': 'Says only certain face masks are effective and others, such as cloth masks, are not.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-04-02T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/18/facebook-posts/face-masks-including-homemade-ones-are-effective-c/',
#      'title': 'Face masks, including homemade ones, are effective COVID-19 protection, experts say',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Says Wisconsin has not had a spike in coronavirus cases that was “statistically significant related to the fact that they had voting.”',
#    'claimant': 'Chip Roy',
#    'claimDate': '2020-05-06T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/18/chip-roy/no-spike-tied-voting-data-leaves-questions/',
#      'title': 'No spike tied to voting, but data leaves questions',
#      'textualRating': 'Mostly True',
#      'languageCode': 'en'}]},
#   {'text': '"Bill Gates worked to end livestock production, and is pushing lab grown meat."',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-04T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/18/facebook-posts/what-bill-gates-has-do-livestock-lab-grown-meat/',
#      'title': 'What Bill Gates has to do with livestock, lab-grown meat',
#      'textualRating': 'Half True',
#      'languageCode': 'en'}]},
#   {'text': 'Nancy Pelosi said, “if you accept a check from Trump, you might as well vote for him.”',
#    'claimant': 'Viral image',
#    'claimDate': '2020-04-15T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/18/viral-image/nancy-pelosi-didnt-say-accepting-check-trump-means/',
#      'title': "Nancy Pelosi didn't say accepting a check from Trump means you should vote for him",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Beachgoers trash Florida beaches with 13,000 pounds of litter after beaches reopen.”',
#    'claimant': 'Facebook',
#    'claimDate': '2020-05-12T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/18/facebook-posts/reopened-florida-beach-leads-more-trash/',
#      'title': 'Reopened Florida beach leads to more trash',
#      'textualRating': 'Mostly True',
#      'languageCode': 'en'}]},
#   {'text': '“Pelosi’s new coronavirus bill allows illegals to receive billions in relief funds in past, current, and future payments.”',
#    'claimant': 'Facebook post',
#    'claimDate': '2020-05-12T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/18/facebook-posts/house-coronavirus-bill-would-aid-immigrants-relati/',
#      'title': 'House coronavirus bill would aid immigrants, relatives cut out of previous aid package',
#      'textualRating': 'Mostly True',
#      'languageCode': 'en'}]},
#   {'text': '“Since the reopening of (Georgia), we’ve seen our COVID rate skyrocket by 40%.”',
#    'claimant': 'Stacey Abrams',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/15/stacey-abrams/stacey-abrams-gets-georgias-reopening-covid-19-tre/',
#      'title': "Stacey Abrams gets Georgia's reopening COVID-19 trend upside down. Cases fell",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '$100B contact tracing bill “is about controlling/tracking population, not about coronavirus.”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-12T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/15/facebook-posts/claim-federal-contact-tracing-bill-not-covid-19-fa/',
#      'title': 'Claim that federal contact tracing bill is not for COVID-19 is false',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“(Retail) milk has gone up 7.5% since this time last year. The price farmers are paid has dropped 23%.”',
#    'claimant': 'Facebook post',
#    'claimDate': '2020-05-02T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/15/facebook-posts/yes-payments-dairy-farmers-have-dropped-even-retai/',
#      'title': 'Yes, payments to dairy farmers have dropped even as retail milk prices rise',
#      'textualRating': 'Mostly True',
#      'languageCode': 'en'}]},
#   {'text': 'Says Gov Tony Evers’ administration deemed dentists non-essential',
#    'claimant': 'Janel Brandtjen',
#    'claimDate': '2020-05-12T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/15/janel-brandtjen/yes-dentists-were-essential-under-wisconsins-safer/',
#      'title': "Yes, dentists were essential under Wisconsin's Safer At Home order.",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Clinton Foundation investigator Kenneth McCormick found dead.”',
#    'claimant': 'Bloggers',
#    'claimDate': '2020-05-14T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/15/blog-posting/oh-my-god-clintons-didnt-kill-kenny/',
#      'title': "Oh my God, the Clintons didn't kill Kenny",
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': 'A girl was “decapitated” in front of her parents by a Somali migrant. Media “covered up” the murder.',
#    'claimant': 'Viral image',
#    'claimDate': '2020-05-12T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/15/viral-image/no-media-arent-covering-girls-murder/',
#      'title': "No, the media aren't covering up a girl's murder",
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': '“It’s not that there’s a virus shield between Canada (4,500 deaths) and the U.S. (80,000 deaths). What exists is a difference in leadership.”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-09T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/15/facebook-posts/fact-checking-why-us-has-more-covid-19-deaths-cana/',
#      'title': 'Fact-checking why the US has more COVID-19 deaths than Canada',
#      'textualRating': 'Half True',
#      'languageCode': 'en'}]},
#   {'text': '"Never in the history of this great republic have we quarantined the healthy."',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/fact-checking-california-reopen-protest-video/',
#      'title': 'Fact-checking a California reopen protest video',
#      'reviewDate': '2020-05-14T22:16:19Z',
#      'textualRating': 'Inaccurate',
#      'languageCode': 'en'}]},
#   {'text': 'Fact-checking a video that claims New York City hospitals are "murdering" COVID-19 patients.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-04-30T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/fact-checking-viral-video-alleging-some-new-york-h/',
#      'title': "Fact-checking viral video alleging some New York hospitals are 'murdering' COVID-19 patients",
#      'textualRating': 'Three claims refuted.',
#      'languageCode': 'en'}]},
#   {'text': '"Obama knew. Clinton knew. Biden knew. Comey knew. Brennan knew. McCabe knew. Strzok knew. Clapper knew. Rosenstein knew. FBI knew. DOJ knew. CIA knew. State knew. They all knew it was a lie, a witch-hunt, a scandal, a plot, a conspiracy, a hoax."',
#    'claimant': 'Diamond and Silk',
#    'claimDate': '2020-05-13T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/michael-flynns-unmasking-what-you-need-know/',
#      'title': "Michael Flynn's unmasking: What you need to know",
#      'reviewDate': '2020-05-14T22:14:26Z',
#      'textualRating': "Document doesn't prove hoax",
#      'languageCode': 'en'}]},
#   {'text': '"What if wearing a mask in public is not effective?"',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/fact-checking-california-reopen-protest-video/',
#      'title': 'Fact-checking a California reopen protest video',
#      'reviewDate': '2020-05-14T22:16:19Z',
#      'textualRating': 'Inaccurate',
#      'languageCode': 'en'}]},
#   {'text': '"As we see unemployment increase to Depression levels, we also see suicide increase, we see domestic violence increase, we see child abuse increase, we see alcohol and drug abuse increase."',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/fact-checking-california-reopen-protest-video/',
#      'title': 'Fact-checking a California reopen protest video',
#      'reviewDate': '2020-05-14T22:16:19Z',
#      'textualRating': 'Accurate',
#      'languageCode': 'en'}]},
#   {'text': 'Joe Biden "and more than a dozen Obama administration officials requested and received the power to unmask Flynn.’"',
#    'claimant': 'Rand Paul',
#    'claimDate': '2020-05-13T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/michael-flynns-unmasking-what-you-need-know/',
#      'title': "Michael Flynn's unmasking: What you need to know",
#      'reviewDate': '2020-05-14T22:14:26Z',
#      'textualRating': 'Biden, others are named',
#      'languageCode': 'en'}]},
#   {'text': '“It’s not the coronavirus that’s killing people. It is the economy.”',
#    'claimant': 'Steven Baker',
#    'claimDate': '2020-04-23T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/14/blog-posting/false-tiktok-claim-high-unemployment-killing-more-/',
#      'title': 'The false TikTok claim that high unemployment is killing more people than the coronavirus',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Gates Foundation stands to make nearly £31.5 billion on a coronavirus vaccine in U.K.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-06T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/14/facebook-posts/no-evidence-gates-foundation-will-profit-coronavir/',
#      'title': 'No evidence the Gates Foundation will profit from a coronavirus vaccine',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '$3 trillion for federal coronavirus stimulus packages is "being borrowed basically from China."',
#    'claimant': 'Rand Paul',
#    'claimDate': '2020-05-06T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/14/rand-paul/no-us-isnt-expected-borrow-heavily-china-pay-covid/',
#      'title': "No, US isn't expected to borrow heavily from China to pay for COVID-19 stimulus",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '"If the DNI is suggesting unmasking is wrong, why did the Trump admin unmask identities 17,000 times in 2018?"',
#    'claimant': 'Tommy Vietor',
#    'claimDate': '2020-05-13T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/michael-flynns-unmasking-what-you-need-know/',
#      'title': "Michael Flynn's unmasking: What you need to know",
#      'reviewDate': '2020-05-14T22:14:26Z',
#      'textualRating': 'DNI data backs claim',
#      'languageCode': 'en'}]},
#   {'text': '"The fatality rate of this virus is in the ballpark of a bad seasonal influenza."',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/fact-checking-california-reopen-protest-video/',
#      'title': 'Fact-checking a California reopen protest video',
#      'reviewDate': '2020-05-14T22:16:19Z',
#      'textualRating': 'Misleading',
#      'languageCode': 'en'}]},
#   {'text': '“Democrats introduce bill to ‘euthanize seniors’ to save Social Security.”',
#    'claimant': 'Bloggers',
#    'claimDate': '2020-05-10T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/14/blog-posting/no-democrats-arent-advocating-euthanizing-senior-c/',
#      'title': "No, Democrats aren't advocating euthanizing senior citizens to save Social Security",
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': '"What if quarantining the healthy doesn’t save lives?"',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/14/fact-checking-california-reopen-protest-video/',
#      'title': 'Fact-checking a California reopen protest video',
#      'reviewDate': '2020-05-14T22:16:19Z',
#      'textualRating': 'Inaccurate',
#      'languageCode': 'en'}]},
#   {'text': '“Clearly, the Obama administration did not leave any kind of game plan for something like this.”',
#    'claimant': 'Mitch McConnell',
#    'claimDate': '2020-05-11T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/14/mitch-mcconnell/evidence-counters-mcconnell-claim-obama-team-left-/',
#      'title': "Evidence counters McConnell claim that Obama team left no pandemic 'game plan' for Trump",
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': 'Says Joe Biden said voting by mail is a way to “fundamentally change this country,” contradicting past statements by Barack Obama and Debbie Wasserman Schultz.',
#    'claimant': 'Republican National Committee',
#    'claimDate': '2020-05-08T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/14/republican-national-committee-republican/rnc-video-takes-biden-obama-wasserman-schultz-out-/',
#      'title': 'RNC video takes Biden, Obama, Wasserman Schultz out of context on mail-in voting',
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': 'Says gloves shouldn’t be worn in public because “if you are wearing the same set of gloves all over town you are only spreading germs everywhere you go.”',
#    'claimant': 'Facebook post',
#    'claimDate': '2020-05-05T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/13/facebook-posts/not-better-wearing-gloves-public-coronavirus/',
#      'title': 'No, you are not better off wearing gloves in public',
#      'textualRating': 'True',
#      'languageCode': 'en'}]},
#   {'text': "Says President Donald Trump implemented “a travel ban that just didn't work, 400,000 people got in from those countries that were subject to the restrictions.”",
#    'claimant': 'Chris Murphy',
#    'claimDate': '2020-05-11T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/13/chris-murphy/sen-chris-murphy-overstates-travel-china-after-tru/',
#      'title': 'Sen. Chris Murphy overstates travel from China after Trump restrictions',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'New York City could pay to house its homeless population in hotel rooms currently sitting vacant, but Mayor Bill de Blasio “has absolutely to this point refused to do that.”',
#    'claimant': 'Coalition for the Homeless',
#    'claimDate': '2020-04-08T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/13/coalition-homeless/fact-checking-claim-about-hotel-rooms-and-homeless/',
#      'title': 'Fact-checking a claim about hotel rooms and the homeless in New York City',
#      'textualRating': 'Mostly True',
#      'languageCode': 'en'}]},
#   {'text': 'Under an 1866 Supreme Court ruling, stay-at-home orders are illegal and can be disregarded with impunity.',
#    'claimant': 'Facebook post',
#    'claimDate': '2020-05-09T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/13/facebook-posts/no-s-not-us-supreme-court-ruling/',
#      'title': "No, that's not a US Supreme Court ruling",
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': 'Actor Tom Selleck praised President Donald Trump in a meeting with Breitbart.',
#    'claimant': 'Bloggers',
#    'claimDate': '2019-05-31T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/12/blog-posting/no-tom-selleck-didnt-praise-trump-breitbart-interv/',
#      'title': "No, Tom Selleck didn't praise Trump in Breitbart interview. Most of the words are from another actor",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“The CDC has recommended mail in voting. That’s what this whole pandemic is about: the election!”',
#    'claimant': 'Facebook',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/12/facebook-posts/mail-voting-amid-covid-19-among-options-recommende/',
#      'title': 'Mail-in voting amid COVID-19 is among the options recommended by CDC, but not the only one',
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': '“The mainstream media pretended there was a deadly surge in COVID cases thanks to Wisconsinites voting.”',
#    'claimant': 'One America News',
#    'claimDate': '2020-05-08T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/12/one-america-news/mainstream-media-surge-COVID-Wisconsin-election/',
#      'title': 'No, the media did not “pretend there was a deadly surge in COVID cases” after Wisconsin election',
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': 'Young people "have a greater chance of being killed by the HPV vaccine than COVID-19.”',
#    'claimant': 'Jeff Shipley',
#    'claimDate': '2020-04-28T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/12/jeff-shipley/covid-19-vs-hpv-vaccine-covid-more-deadly/',
#      'title': 'COVID-19 vs. HPV vaccine: COVID is more deadly',
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': 'Quotes Joe Biden as saying, “The things I did while in elected office should not be made public while I am seeking a higher public office.”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-01T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/12/facebook-posts/story-behind-this-biden-misquote/',
#      'title': "There's a story behind this Biden misquote",
#      'textualRating': 'Half True',
#      'languageCode': 'en'}]},
#   {'text': '"Mitch McConnell said he wanted states to go bankrupt instead of the federal government providing relief. Today, Thom Tillis agreed."',
#    'claimant': 'Cal Cunningham',
#    'claimDate': '2020-04-24T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/12/cal-cunningham/nc-democrat-misrepresents-tillis-position-aid-stat/',
#      'title': 'NC Democrat misrepresents Tillis position on aid for states',
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': 'Says Dr. Anthony Fauci\'s name appears on "4 U.S. patents for a key glycoprotein” used to “create the current COVID-19 epidemic.”',
#    'claimant': 'Jerome Corsi',
#    'claimDate': '2020-04-28T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/12/jerome-corsi/conspiracy-theorist-spreads-false-claim-about-fauc/',
#      'title': 'Conspiracy theorist spreads false claim about Fauci, patents and COVID-19',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Says Attorney General William Barr didn’t cite the "rule of law” in explaining his decision in the Michael Flynn case during a CBS News interview.',
#    'claimant': 'Chuck Todd',
#    'claimDate': '2020-05-10T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/11/chuck-todd/nbcs-chuck-todd-meet-press-leave-out-key-context-s/',
#      'title': "NBC's Chuck Todd, 'Meet the Press' leave out key context in shortened Barr clip",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Barack Obama “is the first ex-president to ever speak against his successor.”',
#    'claimant': 'Tweets',
#    'claimDate': '2020-05-10T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/11/tweets/obama-isnt-first-ex-president-speak-ill-his-succes/',
#      'title': "Obama isn't the first ex-president to speak ill of his successor",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Trump revokes Barack Obama’s security clearance.”',
#    'claimant': 'Bloggers',
#    'claimDate': '2020-05-09T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/11/blog-posting/no-trump-didnt-revoke-obamas-security-clearance/',
#      'title': "No, Trump didn't revoke Obama's security clearance",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Regarding the risks of coronavirus transmission on an airplane, “It’s as safe as an environment as you’re going to find.”',
#    'claimant': 'Gary Kelly',
#    'claimDate': '2020-05-03T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/11/gary-kelly/southwest-ceos-boast-about-airplanes-low-covid-ris/',
#      'title': "Southwest CEO's boast about airplanes' low COVID risk overlooks key concerns",
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': '“Dr. Fauci sat on Microsoft’s board of directors.”',
#    'claimant': 'Viral image',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/11/viral-image/no-anthony-fauci-wasnt-microsofts-board-directors/',
#      'title': "No, Anthony Fauci wasn't on Microsoft's board of directors",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Georgia Gov. Brian Kemp “mandates restaurants reopen”',
#    'claimant': 'Facebook',
#    'claimDate': '2020-04-29T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/facebook-posts/worries-restaurant-owners-are-real-post-saying-geo/',
#      'title': 'Worries for restaurant owners are real, but post saying Georgia Gov. mandated reopening goes too far',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'A photo shows Brian Kemp posing with Gregory McMichael.',
#    'claimant': 'Viral image',
#    'claimDate': '2020-05-06T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/viral-image/no-isnt-photo-brian-kemp-and-gregory-mcmichael/',
#      'title': "No, this isn't a photo of Brian Kemp and Gregory McMichael",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Texas ranks 3rd highest among states for the number of people who have recovered from” the coronavirus.',
#    'claimant': 'Greg Abbott',
#    'claimDate': '2020-05-03T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/greg-abbott/recovery-data-coronavirus-lacking/',
#      'title': 'Recovery data on coronavirus is lacking',
#      'textualRating': 'Half True',
#      'languageCode': 'en'}]},
#   {'text': 'Says Wisconsin Gov. Tony Evers "has never had a real job."',
#    'claimant': 'Don Pridemore',
#    'claimDate': '2020-04-24T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/don-pridemore/gop-state-senate-candidate-base-claim-wisconsin-go/',
#      'title': "GOP State Senate candidate is off base with claim that Wisconsin governor 'never had a real job'",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“New York is one of only 12 states where the average gallon of gas costs more than $2.00.”',
#    'claimant': 'American Automobile Association',
#    'claimDate': '2020-04-27T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/american-automobile-association/era-low-gas-prices-new-york-remains-among-most-exp/',
#      'title': 'In era of low gas prices, New York remains among most expensive in US',
#      'textualRating': 'True',
#      'languageCode': 'en'}]},
#   {'text': 'Says Mike Pence was caught on a hot mic delivering empty boxes of PPE to a nursing home and pretended they were heavy.',
#    'claimant': 'Bloggers',
#    'claimDate': '2020-05-08T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/blog-posting/mike-pence-didnt-pretend-carry-empty-boxes-ppe-cli/',
#      'title': "Mike Pence didn't pretend to carry empty boxes of PPE. The clip is cut off",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“New autopsy reports suggest Jeffrey Epstein most likely died from COVID-19 complications.”',
#    'claimant': 'Viral image',
#    'claimDate': '2020-04-20T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/viral-image/theres-no-new-autopsy-report-linking-jeffrey-epste/',
#      'title': "There's no new autopsy report linking Jeffrey Epstein's death to COVID-19",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Says it’s illegal to hold an absentee-only election or mail ballots to every registered voter',
#    'claimant': 'Chris Kapenga',
#    'claimDate': '2020-04-06T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/chris-kapanga/yes-its-illegal-hold-election-mail-wisconsin/',
#      'title': "Yes, it's illegal to hold an election by mail in Wisconsin",
#      'textualRating': 'True',
#      'languageCode': 'en'}]},
#   {'text': 'Black cats in Vietnam are being killed and consumed as a COVID-19 cure.',
#    'claimant': 'South West News Service',
#    'claimDate': '2020-04-24T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/08/south-west-news-service/Evidence-lacking-that-cats-eaten-as-COVID-19-cure/',
#      'title': 'Evidence lacking that cats eaten as COVID-19 cure',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“So 2 doctors from Bakersfield discover that coronavirus mortality rate is 0.03%. 13x less deadly than what was previously thought! Their analysis has since been banned from YouTube.”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-04-28T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/07/facebook-posts/facebook-post-cites-doctors-widely-disputed-calcul/',
#      'title': "Facebook post cites doctors' widely disputed calculations on COVID-19 death rate",
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': 'Says the current survival rate for COVID-19 in the U.S. is “98.54%”',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-04-14T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/07/facebook-posts/facebook-post-shares-flawed-covid-19-survival-stat/',
#      'title': 'Facebook post shares flawed COVID-19 survival statistic',
#      'textualRating': 'Half True',
#      'languageCode': 'en'}]},
#   {'text': '"It’s very clear this virus was manipulated."',
#    'claimant': 'Dr. Judy Mikovits',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/08/fact-checking-plandemic-documentary-full-false-con/',
#      'title': "Fact-checking 'Plandemic': A documentary full of false conspiracy theories about the coronavirus",
#      'reviewDate': '2020-05-08T13:41:30Z',
#      'textualRating': 'Scientists say it’s not',
#      'languageCode': 'en'}]},
#   {'text': '"I was held in jail with no charges."',
#    'claimant': 'Dr. Judy Mikovits',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/08/fact-checking-plandemic-documentary-full-false-con/',
#      'title': "Fact-checking 'Plandemic': A documentary full of false conspiracy theories about the coronavirus",
#      'reviewDate': '2020-05-08T13:41:30Z',
#      'textualRating': 'Inaccurate spin',
#      'languageCode': 'en'}]},
#   {'text': '"If you’ve ever had a flu vaccine, you were injected with coronaviruses."',
#    'claimant': 'Dr. Judy Mikovits',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/08/fact-checking-plandemic-documentary-full-false-con/',
#      'title': "Fact-checking 'Plandemic': A documentary full of false conspiracy theories about the coronavirus",
#      'reviewDate': '2020-05-08T13:41:30Z',
#      'textualRating': 'Inaccurate',
#      'languageCode': 'en'}]},
#   {'text': 'Hydroxychloroquine is "effective against these families of viruses."',
#    'claimant': 'Dr. Judy Mikovits',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/08/fact-checking-plandemic-documentary-full-false-con/',
#      'title': "Fact-checking 'Plandemic': A documentary full of false conspiracy theories about the coronavirus",
#      'reviewDate': '2020-05-08T13:41:30Z',
#      'textualRating': 'Unproven',
#      'languageCode': 'en'}]},
#   {'text': 'Gas is under $1 in 13 states, but $2.27 in Pennsylvania, because of the governor.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-05-02T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/07/facebook-posts/cant-blame-governor-high-pennsylvania-gas-prices/',
#      'title': "Can't blame governor for high Pennsylvania gas prices",
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': '"Wearing the mask literally activates your own virus. You’re getting sick from your own reactivated coronavirus expressions."',
#    'claimant': 'Dr. Judy Mikovits',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/08/fact-checking-plandemic-documentary-full-false-con/',
#      'title': "Fact-checking 'Plandemic': A documentary full of false conspiracy theories about the coronavirus",
#      'reviewDate': '2020-05-08T13:41:30Z',
#      'textualRating': 'No evidence',
#      'languageCode': 'en'}]},
#   {'text': 'A photo shows Rob Cantrall at a recent Michigan protest.',
#    'claimant': 'Viral image',
#    'claimDate': '2020-05-04T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/07/viral-image/michigan-protest-photo-shows-brian-cash-not-rob-ca/',
#      'title': 'Michigan protest photo shows Brian Cash, not Rob Cantrall',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Immigrants make up a majority of essential workers in places like New York City.”',
#    'claimant': 'Kirsten Gillibrand',
#    'claimDate': '2020-04-21T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/07/kirsten-gillibrand/do-immigrants-make-majority-essential-workers-new-/',
#      'title': 'Do immigrants make up a majority of essential workers in New York City?',
#      'textualRating': 'Mostly True',
#      'languageCode': 'en'}]},
#   {'text': '"The flu vaccines increase the odds by 36% of getting COVID-19."',
#    'claimant': 'Dr. Judy Mikovits',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/08/fact-checking-plandemic-documentary-full-false-con/',
#      'title': "Fact-checking 'Plandemic': A documentary full of false conspiracy theories about the coronavirus",
#      'reviewDate': '2020-05-08T13:41:30Z',
#      'textualRating': 'Inaccurate',
#      'languageCode': 'en'}]},
#   {'text': 'Under the mayor’s COVID-19 order, Kansas City “churchgoers must register with the government.”',
#    'claimant': 'Liberty Counsel',
#    'claimDate': '2020-05-01T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/07/liberty-counsel/no-churchgoers-dont-have-register-government/',
#      'title': "No, churchgoers don't have to register with the government",
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': '"This occurred from SARS 1 within a decade — that’s not naturally occurring."',
#    'claimant': 'Dr. Judy Mikovits',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/08/fact-checking-plandemic-documentary-full-false-con/',
#      'title': "Fact-checking 'Plandemic': A documentary full of false conspiracy theories about the coronavirus",
#      'reviewDate': '2020-05-08T13:41:30Z',
#      'textualRating': 'Wrong explanation',
#      'languageCode': 'en'}]},
#   {'text': 'Media outlets reported that the same boy died 3 times from the coronavirus, in 3 countries.',
#    'claimant': 'Facebook posts',
#    'claimDate': '2020-04-14T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/07/facebook-posts/news-outlets-did-not-use-photo-same-boy-report-3-c/',
#      'title': 'News outlets did not use photo of same boy to report on 3 COVID deaths',
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': 'Hospitals get "$13,000 from Medicare if you call it COVID-19" when a patient dies.',
#    'claimant': 'Dr. Judy Mikovits',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/08/fact-checking-plandemic-documentary-full-false-con/',
#      'title': "Fact-checking 'Plandemic': A documentary full of false conspiracy theories about the coronavirus",
#      'reviewDate': '2020-05-08T13:41:30Z',
#      'textualRating': 'Misleading',
#      'languageCode': 'en'}]},
#   {'text': '"Trump bailed out Wall Street, but not Main Street."',
#    'claimant': 'Lincoln Project',
#    'claimDate': '2020-05-05T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/07/lincoln-project/mourning-america-ad-critical-trump-misleads-bailou/',
#      'title': "Lincoln Project's “Mourning in America” ad critical of Trump misleads on bailouts",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '"Don\'t forget, the cupboard was bare. The last administration left us nothing. We didn\'t have ventilators, we didn\'t have medical equipment, we didn\'t have testing."',
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-05T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/06/donald-trumps-4-biggest-falsehoods-abc-news/',
#      'title': "Donald Trump's 4 biggest falsehoods on ABC News",
#      'reviewDate': '2020-05-06T19:43:01Z',
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': 'Dr. Anthony Fauci "has known for 15 years that chloroquine and … hydroxychloroquine will not only treat a current case of coronavirus but prevent future cases.”',
#    'claimant': 'Bloggers',
#    'claimDate': '2020-04-27T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/06/blog-posting/dont-fall-conspiracy-about-dr-anthony-fauci-hydrox/',
#      'title': "Don't fall for conspiracy about Dr. Anthony Fauci, hydroxychloroquine",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“Governor Andy Beshear has authorized Kentucky teachers to make in-home visits. With parental approval, teachers will inspect the bedroom of each student currently enrolled in K-8.”',
#    'claimant': 'Viral image',
#    'claimDate': '2020-04-29T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/06/viral-image/no-kentucky-teachers-wont-be-conducting-student-be/',
#      'title': "No, Kentucky teachers won't be conducting student bedroom inspections",
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': '"Nancy Pelosi was out there at the end of February, talking about let\'s go dancing in Chinatown in San Francisco, because she wanted to prove that there was no problem. But there was a problem. Schumer was talking in March, about there’s no problem. I banned people from coming in, in January."',
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-05T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/06/donald-trumps-4-biggest-falsehoods-abc-news/',
#      'title': "Donald Trump's 4 biggest falsehoods on ABC News",
#      'reviewDate': '2020-05-06T19:43:01Z',
#      'textualRating': 'Misrepresents what they said',
#      'languageCode': 'en'}]},
#   {'text': '"We’ve still had more deaths to the flu this year than we\'ve had COVID-19."',
#    'claimant': 'Dan Forest',
#    'claimDate': '2020-05-07T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/06/dan-forest/no-flu-hasnt-killed-more-people-coronavirus/',
#      'title': "No, the flu hasn't killed more people than coronavirus",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': 'Models projecting COVID-19 deaths “are talking about without mitigation.”',
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-05T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/06/donald-trump/trump-wrong-covid-19-death-projections-omit-mitiga/',
#      'title': 'Trump wrong that COVID-19 death projections omit revisions based on social distancing',
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '"The tests were broken. You saw that. We had broken tests. They left us nothing."',
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-05T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/06/donald-trumps-4-biggest-falsehoods-abc-news/',
#      'title': "Donald Trump's 4 biggest falsehoods on ABC News",
#      'reviewDate': '2020-05-06T19:43:01Z',
#      'textualRating': 'Pants on Fire',
#      'languageCode': 'en'}]},
#   {'text': '“The flu killed 80,000 people in the U.S. last year”',
#    'claimant': 'Facebook',
#    'claimDate': '2020-04-18T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/06/facebook-posts/facebook-post-exaggerates-seasonal-flu-deaths-last/',
#      'title': 'Facebook post exaggerates seasonal flu deaths for last year',
#      'textualRating': 'Mostly False',
#      'languageCode': 'en'}]},
#   {'text': 'On potential deaths: "Those models that you\'re mentioning are talking about without mitigation."',
#    'claimant': 'Donald Trump',
#    'claimDate': '2020-05-05T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/article/2020/may/06/donald-trumps-4-biggest-falsehoods-abc-news/',
#      'title': "Donald Trump's 4 biggest falsehoods on ABC News",
#      'reviewDate': '2020-05-06T19:43:01Z',
#      'textualRating': 'Mitigation included',
#      'languageCode': 'en'}]},
#   {'text': '"Although intuitively I think it probably seemed like social distancing would be necessary, there was no real scientific basis for believing that, since it had never been studied."',
#    'claimant': 'Laura Ingraham',
#    'claimDate': '2020-05-04T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/06/laura-ingraham/laura-ingraham-wrong-about-no-real-scientific-basi/',
#      'title': "Laura Ingraham wrong about 'no real scientific basis' for social distancing",
#      'textualRating': 'False',
#      'languageCode': 'en'}]},
#   {'text': '“At the end of the year, we put into that federal pot $116 billion more than we take out,” while Kentucky “takes out $148 billion more than they put in.”',
#    'claimant': 'Andrew Cuomo',
#    'claimDate': '2020-04-23T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/05/andrew-cuomo/cuomos-claim-new-yorks-contributions-federal-treas/',
#      'title': "Cuomo's claim on New York's contributions to federal treasury needs clarification",
#      'textualRating': 'Half True',
#      'languageCode': 'en'}]},
#   {'text': '“First volunteer in UK coronavirus vaccine trial has died.”',
#    'claimant': 'Bloggers',
#    'claimDate': '2020-04-25T00:00:00Z',
#    'claimReview': [{'publisher': {'name': 'PolitiFact',
#       'site': 'politifact.com'},
#      'url': 'https://www.politifact.com/factchecks/2020/may/05/blog-posting/no-first-volunteer-uk-covid-19-vaccine-trial-hasnt/',
#      'title': "No, the first volunteer in a UK COVID-19 vaccine trial hasn't died",
#      'textualRating': 'False',
#      'languageCode': 'en'}]}],
#  'nextPageToken': 'CMgB'}

# %%
datetime.datetime.strptime(dict(r.json())['claims'][0]['claimDate'], '%Y-%m-%dT%H:%M:%SZ')
# Out:
# datetime.datetime(2020, 5, 21, 0, 0)

# %%
politifact_dictlist = []

for claim in dict(r.json())['claims']:
    politifact_dictentry = {
        'statement': claim['text'],
        'label':     claim['claimReview'][0]['textualRating'],
        'date':      datetime.datetime.strptime(claim.get('claimDate'), '%Y-%m-%dT%H:%M:%SZ'),
        'speaker':   claim.get('claimant')
    }
    politifact_dictlist.append(politifact_dictentry)

pd.DataFrame(politifact_dictlist)
# Out:
#                                             statement                label  \
# 0   Speaking about border apprehensions, said “We ...            Half True
# 1   “If you look at the one (hydroxychloroquine) s...                False
# 2   If you paid rent in March or April, “they got ...                False
# 3   Says GOP Wisconsin Sen. Patrick Testin is resp...         Mostly False
# 4   “Due to the large number of people who will re...                False
# ..                                                ...                  ...
# 95  “The flu killed 80,000 people in the U.S. last...         Mostly False
# 96  On potential deaths: "Those models that you're...  Mitigation included
# 97  "Although intuitively I think it probably seem...                False
# 98  “At the end of the year, we put into that fede...            Half True
# 99  “First volunteer in UK coronavirus vaccine tri...                False
#
#          date                 speaker
# 0  2020-05-14            Donald Trump
# 1  2020-05-19            Donald Trump
# 2  2020-04-22          Facebook posts
# 3  2020-05-08  Wisconsin State Senate
# 4  2020-05-13          Facebook posts
# ..        ...                     ...
# 95 2020-04-18                Facebook
# 96 2020-05-05            Donald Trump
# 97 2020-05-04          Laura Ingraham
# 98 2020-04-23            Andrew Cuomo
# 99 2020-04-25                Bloggers
#
# [100 rows x 4 columns]

# %%
dict(r.json())['nextPageToken']
# Out:
# 'CGQ'

# %%
from time import sleep

# %%
df=pd.DataFrame(columns=['statement', 'label', 'date', 'speaker'])

# %%
def process_claimentries(json_input):
    
    claims_list = []
    if not dict(json_input).get('claims'):
        return []
    
    for claim in dict(json_input)['claims']:
        dictentry = {
            'statement': claim['text'],
            'label':     claim['claimReview'][0]['textualRating'],
            'date':      datetime.datetime.strptime(claim.get('claimDate'), 
                                                    '%Y-%m-%dT%H:%M:%SZ') if claim.get('claimDate') else None,
            'speaker':   claim.get('claimant')
        }
        claims_list.append(dictentry)
    
    return claims_list
    
def factchecks_bysite(factchecksite, num_entries, app_key, chunk_size=100, language='en', verbose=True):
    
    entries_left = num_entries
    
    first_request = {'languageCode': language,
                     'reviewPublisherSiteFilter': factchecksite, 
                     'pageSize': min(chunk_size, num_entries),
                     'key': app_key }
    entries_left -= chunk_size
    
    if verbose:
        print(f'Retrieving first {chunk_size} claims out of {num_entries}, {entries_left} claims left.')
    
    r = requests.get(url = "https://factchecktools.googleapis.com/v1alpha1/claims:search", params = first_request)
    
    df_list = [pd.DataFrame(process_claimentries(r.json()))]
        
    while (entries_left > 0) and dict(r.json()).get('nextPageToken'):
        print('Done. Pausing for 5 seconds.')
        sleep(5)
        
        next_request = {'languageCode': 'en',
                        'reviewPublisherSiteFilter': 'politifact.com', 
                        'pageSize': min(chunk_size, entries_left),
                        'pageToken': dict(r.json())['nextPageToken'],
                        'key': key }
        
        entries_left -= chunk_size
        print(f'Retrieving next {chunk_size} claims out of {num_entries}, {entries_left} claims left.')
        
        r = requests.get(url = "https://factchecktools.googleapis.com/v1alpha1/claims:search", params = next_request)
        
        df_list.append(pd.DataFrame(process_claimentries(r.json())))

    print('All done.')
    return pd.concat(df_list, ignore_index=True)

# %%
politifact_df = factchecks_bysite('politifact.com', 10, key, chunk_size=5)
# Out:
# Retrieving first 5 claims out of 10, 5 claims left.
# Done. Pausing for 5 seconds.
# Retrieving next 5 claims out of 10, 0 claims left.
# All done.

# %%
politifact_df
# Out:
#                                            statement          label  \
# 0  “Research illustrates a clear correlation betw...           True
# 1  “There were not chemical irritants” used to cl...  Pants on Fire
# 2  A photo shows “the Lincoln Memorial. His head ...          False
# 3  “These ‘peaceful’ protesters burned these hors...          False
# 4  “The 9/11 Memorial in NYC was just defaced wit...          False
# 5  “She’s just casually carrying a body with 1 ha...          False
# 6  “Trump’s star on the Hollywood Walk of Fame ha...          False
# 7  "Last year, there were nine unarmed black peop...   Mostly False
# 8  The man pictured in a mugshot is not Derek Cha...          False
# 9  “This man who was kicked and stomped” was kill...          False
#
#         date         speaker
# 0 2020-05-21  Glenn Grothman
# 1 2020-06-07    William Barr
# 2 2020-06-06     Viral image
# 3 2020-06-01  Facebook posts
# 4 2020-06-05  Facebook posts
# 5 2020-06-03     Viral image
# 6 2020-06-03     Viral image
# 7 2020-06-02     Larry Elder
# 8 2020-06-04     Viral image
# 9 2020-06-03   Facebook post
